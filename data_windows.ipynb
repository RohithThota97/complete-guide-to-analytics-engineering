# %%
import pandas as pd 
df=pd.read_csv("/Users/rohiththota/Local-Repo/complete-guide-to-analytics-engineering/red_30_tech_us_sales_cleaned.csv",parse_dates=["OrderDate"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4976 entries, 0 to 4975
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   EmpID        4976 non-null   int64
#  1   OrderNum     4976 non-null   int64
#  2   OrderDate    4976 non-null   datetime64[ns]
#  3   OrderType    4976 non-null   object
#  4   Quantity     4976 non-null   int64
#  5   Price        4976 non-null   object
#  6   Discount     4976 non-null   object
#  7   Order Total  4976 non-null   float64
# dtypes: datetime64[ns](1), float64(1), int64(3), object(3)
# memory usage: 311.1+ KB
